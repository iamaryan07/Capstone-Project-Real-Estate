# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\aryan\OneDrive\Desktop\Capstone Project\Datasets\independent-house.xlsx')
df.head()
# Out:
#                                       property_name  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon
# 1  5 Bedroom House for sale in Sector 21A Faridabad
# 2  10 Bedroom House for sale in Sushant Lok Phase 1
# 3    21 Bedroom House for sale in Sector 54 Gurgaon
# 4  12 Bedroom House for sale in Sushant Lok Phase 1
#
#                                                 link           society  \
# 0  https://www.99acres.com/5-bhk-bedroom-independ...  Bptp Visionnaire
# 1  https://www.99acres.com/5-bhk-bedroom-independ...               NaN
# 2  https://www.99acres.com/10-bhk-bedroom-indepen...               NaN
# 3  https://www.99acres.com/21-bhk-bedroom-indepen...               NaN
# 4  https://www.99acres.com/12-bhk-bedroom-indepen...               NaN
#
#         price                rate                   area  \
# 0  5.25 Crore   â‚¹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  â‚¹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# ...

# %%
df.drop(columns= 'link', inplace= True)

# %%
df.sample(2)
# Out:
#                                      property_name                   society  \
# 215  5 Bedroom House for sale in Sector 33 Gurgaon  Unitech Uniworld Resorts
# 259    1 Bedroom House for sale in Mianwali Colony   Project Mianwali Colony
#
#          price               rate                     area  \
# 215  9.5 Crore  â‚¹ 23,333/sq.ft.    (418 sq.m.) Plot Area
# 259  1.7 Crore   â‚¹ 9,444/sq.ft.  (167 sq.m.) Carpet Area
#
#                          areaWithType     bedRoom     bathroom       balcony  \
# 215       Plot area 500(418.06 sq.m.)  5 Bedrooms  7 Bathrooms  3+ Balconies
# 259  Carpet area: 1800 (167.23 sq.m.)   1 Bedroom   1 Bathroom   2 Balconies
#
#                                     additionalRoom  \
# 215  Pooja Room,Study Room,Servant Room,Store Room
# 259                                            NaN
#
#                                                address noOfFloor facing  \
# 215                Sector 33 Gurgaon, Gurgaon, Haryana  2 Floors   East
# ...

# %%
df.rename(columns= {'rate': 'price_per_sqft'}, inplace= True)

# %%
df.drop(columns= 'property_id', inplace= True)

# %%
df['property_name'] = df['property_name'].apply(lambda x: x.lower())
df.head(2)
# Out:
#                                       property_name           society  \
# 0    5 bedroom house for sale in sector 70a gurgaon  Bptp Visionnaire
# 1  5 bedroom house for sale in sector 21a faridabad               NaN
#
#         price      price_per_sqft                   area  \
# 0  5.25 Crore   â‚¹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  â‚¹ 105,751/sq.ft.   (50 sq.m.) Plot Area
#
#                   areaWithType     bedRoom     bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)  5 Bedrooms  4 Bathrooms  3+ Balconies
# 1   Plot area 539(50.07 sq.m.)  5 Bedrooms  4 Bathrooms   2 Balconies
#
#                        additionalRoom  \
# 0                        Servant Room
# 1  Store Room,Pooja Room,Servant Room
#
#                                      address noOfFloor      facing  \
# 0  29b, Sector 70A Gurgaon, Gurgaon, Haryana  3 Floors  North-East
# 1     Sector 21A Faridabad, Gurgaon, Haryana  2 Floors         NaN
#
# ...

# %%
df['sector1'] = df['property_name'].str.split('sector').str.get(1).str.split(' ').str.get(0)
df['sector2'] = df['address'].str.split('sector').str.get(1).str.split(' ').str.get(0).str.strip().str.extract(r'(\d+)')[0]
df['sector3'] = df['address'].str.split('Sector').str.get(1).str.split(' ').str.get(0).str.strip().str.extract(r'(\d+)')[0]

# %%
df.sample(4)
# Out:
#                                      property_name           society  \
# 41         2 bedroom house for sale in narsinghpur         sector 37
# 392  3 bedroom house for sale in sector 89 gurgaon  Smart World Gems
# 519            3 bedroom house for sale in bhondsi               NaN
# 665  9 bedroom house for sale in sector 45 gurgaon               NaN
#
#           price     price_per_sqft                       area  \
# 41    55.11 Lac   â‚¹ 7,290/sq.ft.       (70 sq.m.) Plot Area
# 392  1.25 Crore   â‚¹ 8,784/sq.ft.  (132 sq.m.) Built-up Area
# 519      44 Lac   â‚¹ 4,251/sq.ft.     (96 sq.m.) Carpet Area
# 665  4.49 Crore  â‚¹ 24,455/sq.ft.      (171 sq.m.) Plot Area
#
#                                           areaWithType     bedRoom  \
# 41   Plot area 84(70.23 sq.m.)Built Up area: 83 sq....  2 Bedrooms
# 392                  Built Up area: 1423 (132.2 sq.m.)  3 Bedrooms
# 519                     Carpet area: 115 (96.15 sq.m.)  3 Bedrooms
# ...

# %%
df['sector'] = df['sector1'].fillna(df['sector2']).fillna(df['sector3'])
df['sector'].value_counts().sum()
# Out:
# np.int64(466)

# %%
df.drop(columns= ['sector1', 'sector2', 'sector3'], inplace= True)

# %%
df.sample(3)
# Out:
#                                        property_name society       price  \
# 565          5 bedroom house for sale in dlf phase 1     NaN   4.5 Crore
# 526         10 bedroom house for sale in rajiv nagar     NaN     9 Crore
# 695  5 bedroom house for sale in sushant lok phase 3     NaN  8.31 Crore
#
#          price_per_sqft                   area                 areaWithType  \
# 565   â‚¹ 33,333/sq.ft.  (125 sq.m.) Plot Area  Plot area 150(125.42 sq.m.)
# 526  â‚¹ 100,000/sq.ft.   (84 sq.m.) Plot Area   Plot area 900(83.61 sq.m.)
# 695   â‚¹ 24,171/sq.ft.  (319 sq.m.) Plot Area   Plot area 382(319.4 sq.m.)
#
#          bedRoom     bathroom       balcony  \
# 565   5 Bedrooms  5 Bathrooms  3+ Balconies
# 526  10 Bedrooms  5 Bathrooms  3+ Balconies
# 695   5 Bedrooms  6 Bathrooms  3+ Balconies
#
#                                     additionalRoom  \
# 565                                            NaN
# 526                                            NaN
# ...

# %%
col = df.columns.tolist()
col.remove('sector')
col.insert(1, 'sector')
df = df[col]

# %%
df['sector'].value_counts()
# Out:
# sector
#         459
# -33       4
# -57       1
# -105      1
# -5        1
# Name: count, dtype: int64

# %%
df[df['sector'].notna()]['sector']
# Out:
# 0
# 1
# 3
# 6
# 17
#        ..
# 1028
# 1032
# 1034
# 1035
# 1040
# Name: sector, Length: 466, dtype: object

# %%
df.shape
# Out:
# (1041, 20)

# %%
df.head(3)
# Out:
#                                       property_name sector           society  \
# 0    5 bedroom house for sale in sector 70a gurgaon         Bptp Visionnaire
# 1  5 bedroom house for sale in sector 21a faridabad                      NaN
# 2  10 bedroom house for sale in sushant lok phase 1    NaN               NaN
#
#         price      price_per_sqft                   area  \
# 0  5.25 Crore   â‚¹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  â‚¹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# 2   2.1 Crore   â‚¹ 38,251/sq.ft.   (51 sq.m.) Plot Area
#
#                   areaWithType      bedRoom      bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)   5 Bedrooms   4 Bathrooms  3+ Balconies
# 1   Plot area 539(50.07 sq.m.)   5 Bedrooms   4 Bathrooms   2 Balconies
# 2       Plot area 61(51 sq.m.)  10 Bedrooms  10 Bathrooms  3+ Balconies
#
#                        additionalRoom  \
# 0                        Servant Room
# 1  Store Room,Pooja Room,Servant Room
# ...

# %%
df.rename(columns= {'Unnamed: 16': 'description'}, inplace= True)

# %%
df.rename(columns= {'noOfFloor': 'floorNum'}, inplace= True)

# %%
df['price'] = df['price'].apply(
    lambda x: float(x.split(' ')[0]) / 100 if isinstance(x, str) and 'Lac' in x
    else float(x.split(' ')[0]) if isinstance(x, str) and 'Crore' in x
    else x
)

# %%
df['price'].value_counts()
# Out:
# price
# 3.50    19
# 5.50    17
# 6.50    16
# 6.00    14
# 5.00    13
#         ..
# 3.80     1
# 7.45     1
# 7.42     1
# 6.09     1
# 2.98     1
# Name: count, Length: 302, dtype: int64

# %%
df.head(1)
# Out:
#                                     property_name sector           society  \
# 0  5 bedroom house for sale in sector 70a gurgaon         Bptp Visionnaire
#
#   price     price_per_sqft                   area  \
# 0  5.25  â‚¹ 20,115/sq.ft.  (242 sq.m.) Plot Area
#
#                   areaWithType     bedRoom     bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)  5 Bedrooms  4 Bathrooms  3+ Balconies
#
#   additionalRoom                                    address  floorNum  \
# 0   Servant Room  29b, Sector 70A Gurgaon, Gurgaon, Haryana  3 Floors
#
#        facing    agePossession  \
# 0  North-East  0 to 1 Year Old
#
#                                      nearbyLocations  description  \
# 0  ['Good Earth City Center 2', 'Kunskapsskolan I...          NaN
#
#                                       furnishDetails  \
# 0  ['1 Wardrobe', '1 Fan', '1 Exhaust Fan', '1 Ge...
#
#                                             features  \
# ...

# %%
df['price_per_sqft'] = df['price_per_sqft'].str.split('â‚¹').str.get(1).str.split('/').str.get(0).str.replace(',', '').astype(float)

# %%
df.head(3)
# Out:
#                                       property_name sector           society  \
# 0    5 bedroom house for sale in sector 70a gurgaon         Bptp Visionnaire
# 1  5 bedroom house for sale in sector 21a faridabad                      NaN
# 2  10 bedroom house for sale in sushant lok phase 1    NaN               NaN
#
#   price  price_per_sqft                   area                 areaWithType  \
# 0  5.25         20115.0  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1   5.7        105751.0   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2   2.1         38251.0   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
#
#        bedRoom      bathroom       balcony  \
# 0   5 Bedrooms   4 Bathrooms  3+ Balconies
# 1   5 Bedrooms   4 Bathrooms   2 Balconies
# 2  10 Bedrooms  10 Bathrooms  3+ Balconies
#
#                        additionalRoom  \
# 0                        Servant Room
# 1  Store Room,Pooja Room,Servant Room
# 2                        Servant Room
#
# ...

# %%
with pd.option_context('display.max_rows', None):
    print(df['area'].value_counts())
# Out:
# area
# (301 sq.m.) Plot Area            44
# (84 sq.m.) Plot Area             37
# (251 sq.m.) Plot Area            31
# (167 sq.m.) Plot Area            26
# (420 sq.m.) Plot Area            24
# (226 sq.m.) Plot Area            22
# (418 sq.m.) Plot Area            21
# (125 sq.m.) Plot Area            19
# (201 sq.m.) Plot Area            18
# (180 sq.m.) Plot Area            18
# (135 sq.m.) Plot Area            16
# (50 sq.m.) Plot Area             16
# (209 sq.m.) Plot Area            14
# (42 sq.m.) Plot Area             12
# (171 sq.m.) Plot Area            12
# (293 sq.m.) Plot Area            11
# (334 sq.m.) Plot Area            11
# (220 sq.m.) Plot Area            11
# (33 sq.m.) Plot Area             11
# (264 sq.m.) Plot Area            10
# (145 sq.m.) Plot Area             9
# (51 sq.m.) Plot Area              9
# (136 sq.m.) Plot Area             8
# (502 sq.m.) Plot Area             8
# (151 sq.m.) Plot Area             8
# (161 sq.m.) Plot Area             7
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
df['area'].value_counts()
# Out:
# area
# (301 sq.m.) Plot Area        44
# (84 sq.m.) Plot Area         37
# (251 sq.m.) Plot Area        31
# (167 sq.m.) Plot Area        26
# (420 sq.m.) Plot Area        24
#                              ..
# (250 sq.m.) Plot Area         1
# (4699 sq.m.) Plot Area        1
# (155 sq.m.) Plot Area         1
# (510 sq.m.) Plot Area         1
# (248 sq.m.) Built-up Area     1
# Name: count, Length: 378, dtype: int64

# %%
df[df['area'] == 467-681]
# Out:
# Empty DataFrame
# Columns: [property_name, sector, society, price, price_per_sqft, area, areaWithType, bedRoom, bathroom, balcony, additionalRoom, address, floorNum, facing, agePossession, nearbyLocations, description, furnishDetails, features, rating]
# Index: []

# %%
df.head(2)
# Out:
#                                       property_name sector           society  \
# 0    5 bedroom house for sale in sector 70a gurgaon         Bptp Visionnaire
# 1  5 bedroom house for sale in sector 21a faridabad                      NaN
#
#   price  price_per_sqft                   area                 areaWithType  \
# 0  5.25         20115.0  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1   5.7        105751.0   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
#
#       bedRoom     bathroom       balcony                      additionalRoom  \
# 0  5 Bedrooms  4 Bathrooms  3+ Balconies                        Servant Room
# 1  5 Bedrooms  4 Bathrooms   2 Balconies  Store Room,Pooja Room,Servant Room
#
#                                      address  floorNum      facing  \
# 0  29b, Sector 70A Gurgaon, Gurgaon, Haryana  3 Floors  North-East
# 1     Sector 21A Faridabad, Gurgaon, Haryana  2 Floors         NaN
#
# ...

# %%
df.drop(columns= 'area', inplace= True)

# %%
df['area'] = (df['price']*10000000)/df['price_per_sqft']

df.head(2)
# Out:
#                                       property_name sector           society  \
# 0    5 bedroom house for sale in sector 70a gurgaon         Bptp Visionnaire
# 1  5 bedroom house for sale in sector 21a faridabad                      NaN
#
#   price  price_per_sqft                 areaWithType     bedRoom     bathroom  \
# 0  5.25         20115.0  Plot area 290(242.48 sq.m.)  5 Bedrooms  4 Bathrooms
# 1   5.7        105751.0   Plot area 539(50.07 sq.m.)  5 Bedrooms  4 Bathrooms
#
#         balcony                      additionalRoom  \
# 0  3+ Balconies                        Servant Room
# 1   2 Balconies  Store Room,Pooja Room,Servant Room
#
#                                      address  floorNum      facing  \
# 0  29b, Sector 70A Gurgaon, Gurgaon, Haryana  3 Floors  North-East
# 1     Sector 21A Faridabad, Gurgaon, Haryana  2 Floors         NaN
#
#       agePossession                                    nearbyLocations  \
# ...

# %%
df['area'] = df['area'].astype(float)

# %%
df['area'] = round(df['area'], 0)

# %%
cols = df.columns.tolist()
cols.remove('area')
cols.insert(5, 'area')  # Makes 'sector' the second column (index 1)
df = df[cols]

# %%
df.head(1)
# Out:
#                                     property_name sector           society  \
# 0  5 bedroom house for sale in sector 70a gurgaon         Bptp Visionnaire
#
#   price  price_per_sqft    area                 areaWithType     bedRoom  \
# 0  5.25         20115.0  2610.0  Plot area 290(242.48 sq.m.)  5 Bedrooms
#
#       bathroom       balcony additionalRoom  \
# 0  4 Bathrooms  3+ Balconies   Servant Room
#
#                                      address  floorNum      facing  \
# 0  29b, Sector 70A Gurgaon, Gurgaon, Haryana  3 Floors  North-East
#
#      agePossession                                    nearbyLocations  \
# 0  0 to 1 Year Old  ['Good Earth City Center 2', 'Kunskapsskolan I...
#
#    description                                     furnishDetails  \
# 0          NaN  ['1 Wardrobe', '1 Fan', '1 Exhaust Fan', '1 Ge...
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Private Gard...
#
# ...

# %%
df['bedRoom'] = df['bedRoom'].astype(str)
df['bathroom'] = df['bathroom'].astype(str)
df['balcony'] = df['balcony'].astype(str)

# %%
df['bedRoom'] = df['bedRoom'].str.split(' ').str.get(0).astype(float)
df['bathroom'] = df['bathroom'].str.split(' ').str.get(0).astype(float)
df['balcony'] = df['balcony'].str.split(' ').str.get(0)

# %%
df.sample(3)
# Out:
#                                         property_name sector     society  \
# 364    5 bedroom house for sale in sector 108 gurgaon         Sobha City
# 605  3 bedroom house for sale in huda saraswati vihar    NaN         NaN
# 281           6 bedroom house for sale in dlf phase 2    NaN         NaN
#
#     price  price_per_sqft    area                        areaWithType  \
# 364   NaN             NaN     NaN  Built Up area: 7331 (681.07 sq.m.)
# 605  0.65        144444.0    45.0            Plot area 45(4.18 sq.m.)
# 281  16.0         26667.0  6000.0  Built Up area: 6000 (557.42 sq.m.)
#
#      bedRoom  bathroom balcony additionalRoom  \
# 364      5.0       1.0      No            NaN
# 605      3.0       3.0       2            NaN
# 281      6.0       5.0       2            NaN
#
#                                                address  floorNum facing  \
# 364   Sector 109, Sector 108 Gurgaon, Gurgaon, Haryana  1 Floors    NaN
# ...

# %%
df['floorNum'] = df['floorNum'].str.split(' ').str.get(0)

# %%
df['floorNum'].value_counts()
# Out:
# floorNum
# 3     309
# 2     300
# 1     183
# 4     139
# 5       9
# 0       6
# 14      3
# 6       3
# 10      2
# 11      2
# 12      2
# 21      1
# 13      1
# 27      1
# 02      1
# 20      1
# 41      1
# 51      1
# 16      1
# 33      1
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (1041, 20)

# %%
df['additionalRoom'].fillna('not available',inplace=True)
df['additionalRoom'] = df['additionalRoom'].str.lower()

# %%
df['balcony'].value_counts()
# Out:
# balcony
# 3+     374
# 2      224
# 3      163
# No     118
# 1      108
# nan     54
# Name: count, dtype: int64

# %%
df = df[~df['bedRoom'].isnull()]

# %%
df['balcony'] = df['balcony'].str.replace('No','0')

# %%
df.shape
# Out:
# (987, 20)

# %%
df.head()
# Out:
#                                       property_name sector           society  \
# 0    5 bedroom house for sale in sector 70a gurgaon         Bptp Visionnaire
# 1  5 bedroom house for sale in sector 21a faridabad                      NaN
# 2  10 bedroom house for sale in sushant lok phase 1    NaN               NaN
# 3    21 bedroom house for sale in sector 54 gurgaon                      NaN
# 4  12 bedroom house for sale in sushant lok phase 1    NaN               NaN
#
#   price  price_per_sqft    area                 areaWithType  bedRoom  \
# 0  5.25         20115.0  2610.0  Plot area 290(242.48 sq.m.)      5.0
# 1   5.7        105751.0   539.0   Plot area 539(50.07 sq.m.)      5.0
# 2   2.1         38251.0   549.0       Plot area 61(51 sq.m.)     10.0
# 3   5.0         43066.0  1161.0  Plot area 129(107.86 sq.m.)     21.0
# 4   3.0         53763.0   558.0    Plot area 62(51.84 sq.m.)     12.0
#
#    bathroom balcony                      additionalRoom  \
# ...
