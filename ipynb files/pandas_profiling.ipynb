# %%
import pandas as pd
from summarytools import dfSummary

df = pd.read_csv(r'C:\Users\aryan\OneDrive\Desktop\Capstone Project\Data Preprocessing\gurgaon_properties_cleaned_v2.csv').drop_duplicates()
dfSummary(df)
# Out:
# <style type="text/css">
# #T_880b5 thead>tr>th {
#   text-align: left;
# }
# #T_880b5_row0_col0, #T_880b5_row1_col0, #T_880b5_row2_col0, #T_880b5_row3_col0, #T_880b5_row4_col0, #T_880b5_row5_col0, #T_880b5_row6_col0, #T_880b5_row7_col0, #T_880b5_row8_col0, #T_880b5_row9_col0, #T_880b5_row10_col0, #T_880b5_row11_col0, #T_880b5_row12_col0, #T_880b5_row13_col0, #T_880b5_row14_col0, #T_880b5_row15_col0, #T_880b5_row16_col0, #T_880b5_row17_col0, #T_880b5_row18_col0, #T_880b5_row19_col0, #T_880b5_row20_col0, #T_880b5_row21_col0, #T_880b5_row22_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# ...
